# %%
import matplotlib.pyplot as plt
import numpy as np

# 10 steps

# fixed
rfne = [0.19265528, 0.1591418 , 0.13744009, 0.10633639, 0.1087247 ,
       0.11561229, 0.12296584, 0.14428958, 0.15547724, 0.1869141 ]

r2 = [0.98441339, 0.98764305, 0.98997569, 0.99355709, 0.99284875,
       0.99217647, 0.99133983, 0.98881963, 0.98801132, 0.98482858]

# rfne = [0.14407657, 0.11743953, 0.10347318, 0.0928745 , 0.09497214,
#        0.10573346, 0.10545881, 0.1200785 , 0.13954379, 0.15427008]

# r2 = [0.99070435, 0.99273855, 0.99399191, 0.99482854, 0.99438085,
#        0.9933009 , 0.99352868, 0.99214116, 0.99055607, 0.98951555]

# changeable
# rfne_post = [0.18097433, 0.15752806, 0.14229411, 0.11445365, 0.10783172,
#        0.10290316, 0.10406045, 0.11451121, 0.12106457, 0.16247243]

# r2_post = [0.98603136, 0.98760399, 0.98907104, 0.99246343, 0.99313133,
#        0.99382055, 0.9938173 , 0.99283936, 0.99255227, 0.98824785]

rfne_post = [0.3675676 , 0.31697685, 0.2851046 , 0.21220757, 0.19470926,
       0.18869007, 0.19266918, 0.23202172, 0.28580713, 0.35488155]

r2_post = [0.95454001, 0.96163149, 0.96569936, 0.97878067, 0.98122503,
       0.98241441, 0.98219139, 0.97638862, 0.9673457 , 0.95649369]

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

labels = ['fixed T (30 epochs)', 'changeable T (30 epochs)']

# Line plot
ax1.plot(rfne, 'b-o', label = labels[0])
ax1.plot(rfne_post, 'b--o', label = labels[1])
ax1.set_ylim(0., 0.4)
# ax1.set_title('Line Plot')
ax1.set_xlabel('Interpolation step')
ax1.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax1.set_ylabel('RFNE')
ax1.grid(True)
ax1.legend()

ax2.plot(r2, 'r-o', label = labels[0])
ax2.plot(r2_post, 'r--o', label = labels[1])
ax2.set_ylim(0.9, 1.0)
# ax1.set_title('Line Plot')
ax2.set_xlabel('Interpolation step')
ax2.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax2.set_ylabel('Pearson correlation')
ax2.grid(True)
ax2.legend()

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5 steps

# %%
import matplotlib.pyplot as plt
import numpy as np

# 10 steps

# fixed
rfne = [0.5154933 , 0.45721486, 0.40925717, 0.3933526 , 0.44182858]

r2 = [0.90700874, 0.91447628, 0.92382214, 0.92904081, 0.91461558]

# changeable
rfne_post = [0.25435916, 0.17995335, 0.12456822, 0.13427955, 0.21138129]

r2_post = [0.97160022, 0.98359633, 0.9911875 , 0.99053217, 0.9796121 ]

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

labels = ['fixed T (30 epochs)', 'changeable T (30 epochs)']

# Line plot
ax1.plot(rfne, 'b-o', label = labels[0])
ax1.plot(rfne_post, 'b--o', label = labels[1])
ax1.set_ylim(0., 0.6)
# ax1.set_title('Line Plot')
ax1.set_xlabel('Interpolation step')
ax1.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax1.set_ylabel('RFNE')
ax1.grid(True)
ax1.legend()

ax2.plot(r2, 'r-o', label = labels[0])
ax2.plot(r2_post, 'r--o', label = labels[1])
ax2.set_ylim(0.9, 1.0)
# ax1.set_title('Line Plot')
ax2.set_xlabel('Interpolation step')
ax2.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax2.set_ylabel('Pearson correlation')
ax2.grid(True)
ax2.legend()

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# # 20 steps

# %%
import matplotlib.pyplot as plt
import numpy as np

# 10 steps

# fixed
rfne = [0.57401186, 0.48356098, 0.4349517 , 0.43077582, 0.4649471 ,
       0.50730264, 0.5755025 , 0.646295  , 0.7181823 , 0.799976  ,
       0.46211717, 0.4782859 , 0.4837243 , 0.481366  , 0.4609142 ,
       0.448053  , 0.51782763, 0.5399553 , 0.57880366, 0.60309625]

r2 = [0.92154834, 0.92874758, 0.92794068, 0.91653352, 0.89503149,
       0.87210435, 0.83126078, 0.78753757, 0.74112801, 0.68902339,
       0.88769823, 0.88165811, 0.88057103, 0.88448862, 0.8957139 ,
       0.90632909, 0.8796371 , 0.86747864, 0.85677266, 0.84302818]

# changeable
rfne_post = [0.47825608, 0.40831488, 0.39381522, 0.37583697, 0.4071461 ,
       0.44815004, 0.49870166, 0.54820096, 0.58931375, 0.61450744,
       0.63967335, 0.6782728 , 0.68613786, 0.6971689 , 0.6709529 ,
       0.62910706, 0.5852097 , 0.4977967 , 0.42214543, 0.5528956 ]

r2_post = [0.94190093, 0.94930044, 0.94587546, 0.94158274, 0.92513719,
       0.90403405, 0.87663881, 0.84716369, 0.8210066 , 0.80343031,
       0.78678381, 0.76961282, 0.77072033, 0.77254932, 0.79345182,
       0.8230193 , 0.85117381, 0.89279889, 0.92866522, 0.87392047]

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

labels = ['fixed T (30 epochs)', 'changeable T (30 epochs)']

# Line plot
ax1.plot(rfne, 'b-o', label = labels[0])
ax1.plot(rfne_post, 'b--o', label = labels[1])
# ax1.set_ylim(0., 0.4)
# ax1.set_title('Line Plot')
ax1.set_xlabel('Interpolation step')
ax1.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax1.set_ylabel('RFNE')
ax1.grid(True)
ax1.legend()

ax2.plot(r2, 'r-o', label = labels[0])
ax2.plot(r2_post, 'r--o', label = labels[1])
# ax2.set_ylim(0.9, 1.0)
# ax1.set_title('Line Plot')
ax2.set_xlabel('Interpolation step')
ax2.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax2.set_ylabel('Pearson correlation')
ax2.grid(True)
ax2.legend()

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# # 15 steps

# %%
import matplotlib.pyplot as plt
import numpy as np

# fixed
rfne = [0.545086  , 0.4567849 , 0.38745964, 0.36859798, 0.38411278,
       0.41967538, 0.47578603, 0.5382122 , 0.6212401 , 0.7074365 ,
       0.44199198, 0.48087457, 0.53661615, 0.54804593, 0.5753459 ]

r2 = [0.92270461, 0.93442775, 0.94230173, 0.93944233, 0.93025171,
       0.91425496, 0.88913088, 0.86051447, 0.82257065, 0.78231391,
       0.90654455, 0.89197966, 0.86798864, 0.86736845, 0.86010271]

# changeable
rfne_post = [0.42383912, 0.38425747, 0.35564208, 0.28588828, 0.28040117,
       0.2667936 , 0.2575494 , 0.24962468, 0.24660356, 0.24023929,
       0.2428029 , 0.27281117, 0.30707952, 0.36513808, 0.41444778]

r2_post = [0.94770856, 0.95201298, 0.95377411, 0.96523401, 0.96429319,
       0.96567217, 0.96700271, 0.96829596, 0.96937136, 0.9713904 ,
       0.97214239, 0.9674513 , 0.96374393, 0.95393728, 0.94812683]

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

labels = ['fixed T (30 epochs)', 'changeable T (30 epochs)']

# Line plot
ax1.plot(rfne, 'b-o', label = labels[0])
ax1.plot(rfne_post, 'b--o', label = labels[1])
# ax1.set_ylim(0., 0.4)
# ax1.set_title('Line Plot')
ax1.set_xlabel('Interpolation step')
ax1.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax1.set_ylabel('RFNE')
ax1.grid(True)
ax1.legend()

ax2.plot(r2, 'r-o', label = labels[0])
ax2.plot(r2_post, 'r--o', label = labels[1])
# ax2.set_ylim(0.9, 1.0)
# ax1.set_title('Line Plot')
ax2.set_xlabel('Interpolation step')
ax2.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax2.set_ylabel('Pearson correlation')
ax2.grid(True)
ax2.legend()

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# ## evaluate for multiple metrics

# %%
import matplotlib.pyplot as plt
import numpy as np

# 10 steps

# # changable T
# rfne = [0.52955544, 0.5277196 , 0.60910076, 0.63171244, 0.9655156 ]
# r2 = [0.8671184 , 0.83236858, 0.77850136, 0.79085827, 0.65177189]
# ssim = [0.39880548, 0.37309817, 0.35238445, 0.37858417, 0.14352508]

# rfne = [0.53350526, 0.5763759 , 0.5972318 , 0.6051979 , 0.6086587 ,
#        0.61371213, 0.60421026, 0.59360355, 0.5786728 , 0.5219792 ]

# r2 = [0.88109548, 0.8355952 , 0.80400332, 0.78433389, 0.7743583 ,
#        0.77247971, 0.78385855, 0.80402647, 0.8340926 , 0.88156413]

# ssim = [0.69849592, 0.66920816, 0.65595899, 0.65123924, 0.65402749,
#        0.63632784, 0.64333283, 0.65576322, 0.67036038, 0.69594137]


rfne = [0.566403  , 0.6384123 , 0.6742603 , 0.70223475, 0.72192955,
       0.7347434 , 0.74576765, 0.7551765 , 0.7579385 , 0.75851053,
       0.7557609 , 0.7528926 , 0.7397815 , 0.7332926 , 0.7323432 ,
       0.719894  , 0.6626005 , 0.58962053]

r2 = [0.8776286 , 0.82046777, 0.77696104, 0.73983792, 0.71060039,
       0.6866997 , 0.67128856, 0.65612709, 0.65153007, 0.65079481,
       0.65622558, 0.66291772, 0.67965842, 0.7000246 , 0.72304178,
       0.75727428, 0.80700727, 0.86740803]

ssim = [0.66498781, 0.62778053, 0.61382569, 0.60743123, 0.60247989,
       0.60145656, 0.5947788 , 0.58410146, 0.5951702 , 0.58941399,
       0.59265884, 0.59436065, 0.6095742 , 0.60467129, 0.6027283 ,
       0.60552696, 0.62924835, 0.66626895]

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# labels = ['fixed T (30 epochs)', 'changeable T (30 epochs)']

labels = ['changeable T (300 epochs)']

# Line plot
ax1.plot(rfne, 'b-o', label = labels[0])
# ax1.plot(rfne_post, 'b--o', label = labels[1])
# ax1.set_ylim(0., 0.6)
# ax1.set_title('Line Plot')
ax1.set_xlabel('Interpolation step')
ax1.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax1.set_ylabel('RFNE')
ax1.grid(True)
ax1.legend()

ax2.plot(r2, 'r-o', label = labels[0])
# ax2.plot(r2_post, 'r--o', label = labels[1])
# ax2.set_ylim(0.9, 1.0)
# ax1.set_title('Line Plot')
ax2.set_xlabel('Interpolation step')
ax2.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax2.set_ylabel('Pearson correlation')
ax2.grid(True)
ax2.legend()
# Adjust layout and display
plt.tight_layout()
plt.show()

fig, ax3 = plt.subplots(1, 1, figsize=(4, 3))

ax3.plot(ssim, color='orange', linestyle='-', marker='o', label = labels[0])
# ax2.plot(r2_post, 'r--o', label = labels[1])
# ax2.set_ylim(0.9, 1.0)
# ax1.set_title('Line Plot')
ax3.set_xlabel('Interpolation step')
ax3.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax3.set_ylabel('SSIM')
ax3.grid(True)
ax3.legend()

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 4 steps

# 1 encoder
rfne = [0.3794114 , 0.38491717, 0.3860859 , 0.3849962 ]
r2 = [0.92262465, 0.90952342, 0.90946831, 0.92171527]
ssim = [0.81555388, 0.80811355, 0.80615608, 0.81340892]

# 2 encoders
rfne_post = [0.33604202, 0.3507932 , 0.35246676, 0.3400091 ]
r2_post = [0.9396349 , 0.9235879 , 0.92337424, 0.93984705]
ssim_post = [0.75898395, 0.75449045, 0.7518759, 0.75926282]

# Create a figure with two subplots
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 4))

labels = ['1 encoder (153M)', '2 encoders (244M)']

# Line plot
ax1.plot(rfne, 'b-o', label = labels[0])
ax1.plot(rfne_post, 'b--o', label = labels[1])
ax1.set_ylim(0.3, 0.4)
# ax1.set_title('Line Plot')
ax1.set_xlabel('Interpolation step')
ax1.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax1.set_ylabel('RFNE')
ax1.grid(True)
ax1.legend()

ax2.plot(r2, 'r-o', label = labels[0])
ax2.plot(r2_post, 'r--o', label = labels[1])
ax2.set_ylim(0.9, 1.0)
# ax1.set_title('Line Plot')
ax2.set_xlabel('Interpolation step')
ax2.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax2.set_ylabel('Pearson correlation')
ax2.grid(True)
ax2.legend()

ax3.plot(ssim, color='orange', linestyle='-', marker='o',  label = labels[0])
ax3.plot(ssim_post, color='orange', linestyle='--', marker='o',  label = labels[1])
ax3.set_ylim(0.7, 0.9)
# ax3.set_title('Line Plot')
ax3.set_xlabel('Interpolation step')
ax3.set_xticks(np.arange(len(rfne)), [str(i) for i in range(1, len(rfne) + 1)])
ax3.set_ylabel('SSIM')
ax3.grid(True)
ax3.legend()

# Adjust layout and display
plt.tight_layout()
plt.show()
